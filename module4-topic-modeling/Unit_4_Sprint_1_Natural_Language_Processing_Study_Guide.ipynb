# %% [markdown]
# This study guide should reinforce and provide practice for all of the concepts you have seen in the past week. There are a mix of written questions and coding exercises, both are equally important to prepare you for the sprint challenge as well as to be able to speak on these topics comfortably in interviews and on the job.
#
# If you get stuck or are unsure of something remember the 20 minute rule. If that doesn't help, then research a solution with google and stackoverflow. Only once you have exausted these methods should you turn to your Team Lead - they won't be there on your SC or during an interview. That being said, don't hesitate to ask for help if you truly are stuck.
#
# Have fun studying!

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bundickm/Study-Guides/master/data/cannabis.csv')
print('Shape:', df.shape, '\n')
df.head()
# Out:
# Shape: (2351, 6)
#            Strain    Type  Rating                                     Effects  \
# 0          100-Og  hybrid     4.0  Creative,Energetic,Tingly,Euphoric,Relaxed
# 1  98-White-Widow  hybrid     4.7    Relaxed,Aroused,Creative,Happy,Energetic
# 2            1024  sativa     4.4   Uplifted,Happy,Relaxed,Energetic,Creative
# 3        13-Dawgs  hybrid     4.2     Tingly,Creative,Hungry,Relaxed,Uplifted
# 4        24K-Gold  hybrid     4.6   Happy,Relaxed,Euphoric,Uplifted,Talkative
#
#                       Flavor  \
# 0        Earthy,Sweet,Citrus
# 1      Flowery,Violet,Diesel
# 2    Spicy/Herbal,Sage,Woody
# 3  Apricot,Citrus,Grapefruit
# 4       Citrus,Earthy,Orange
#
#                                          Description
# 0  $100 OG is a 50/50 hybrid strain that packs a ...
# 1  The ‘98 Aloha White Widow is an especially pot...
# 2  1024 is a sativa-dominant hybrid bred in Spain...
# 3  13 Dawgs is a hybrid of G13 and Chemdawg genet...
# 4  Also known as Kosher Tangie, 24k Gold is a 60%...

# %%
df.sort_values(by="Rating", ascending=False)[:10]
# Out:
#                          Strain    Type  Rating  \
# 671                    Dizzy-Og  hybrid     5.0
# 2120                     Tardis  sativa     5.0
# 2117             Tangier-Chilly  hybrid     5.0
# 497                  Cherwillie  hybrid     5.0
# 2112  Tangerine-Trainwreck-Haze  sativa     5.0
# 1345               Mangolicious  indica     5.0
# 193          Berts-Cookie-Dough  hybrid     5.0
# 194        Bertberry-Cheesecake  sativa     5.0
# 2104                 Tangenesia  hybrid     5.0
# 1721               Purple-Swish  indica     5.0
#
#                                            Effects  \
# 671           Giggly,Relaxed,Uplifted,Happy,Hungry
# 2120   Talkative,Creative,Euphoric,Focused,Aroused
# 2117  Talkative,Uplifted,Creative,Energetic,Giggly
# 497       Creative,Energetic,Happy,Relaxed,Focused
# 2112  Euphoric,Aroused,Uplifted,Creative,Energetic
# 1345         Uplifted,Focused,Relaxed,Giggly,Happy
# 193                Uplifted,Energetic,Happy,Hungry
# 194   Uplifted,Creative,Euphoric,Focused,Energetic
# 2104                                          None
# 1721          Happy,Energetic,Sleepy,Giggly,Hungry
#
#                           Flavor  \
# 671   Sweet,Pungent,Spicy/Herbal
# 2120   Sweet,Diesel,Spicy/Herbal
# 2117          Citrus,Orange,Pine
# 497      Sweet,Strawberry,Citrus
# 2112         Sweet,Citrus,Orange
# 1345    Sweet,Tropical,Pineapple
# 193                         None
# 194      Cheese,Berry,Tree,Fruit
# 2104                        None
# 1721           Berry,Sweet,Grape
#
#                                             Description
# 671   Dizzy OG took 2nd place for Best Medical Hybri...
# 2120  Tardis, or “The Tardis,” is a sativa-dominant ...
# 2117  Tangier Chilly by Mr. Mack’s Snacks is an homa...
# 497   CherWillie is the sativa-dominant hybrid cross...
# 2112  Tangerine Trainwreck Haze is another beautiful...
# 1345  Mangolicious is an indica-dominant cross of Bi...
# 193   Bert’s Cookie Dough by Los Angeles Kush is a h...
# 194   Bertberry Cheesecake by Bert Baccarat is a bri...
# 2104  Tangenesia is a heady bud crafted from even he...
# 1721  Purple Swish is an intensely fruity indica str...

# %%
df['Rating'].value_counts(normalize=True)
# Out:
# 4.5    0.134836
# 4.3    0.126329
# 4.4    0.120800
# 4.6    0.102935
# 4.2    0.095704
# 5.0    0.089324
# 4.7    0.069758
# 4.8    0.067631
# 4.0    0.044236
# 4.1    0.042960
# 0.0    0.030200
# 4.9    0.025096
# 3.9    0.012335
# 3.8    0.009783
# 3.7    0.006806
# 3.0    0.005530
# 3.6    0.004679
# 3.5    0.003828
# 3.4    0.002127
# 3.2    0.001276
# 3.3    0.001276
# 2.0    0.000851
# 2.8    0.000425
# 1.0    0.000425
# 3.1    0.000425
# 2.5    0.000425
# Name: Rating, dtype: float64

# %%
low_qual = df[(df['Rating'] < 3.0) & (df['Rating'] > 0)]
print(low_qual.shape)
# Out:
# (5, 6)

# %%
sample = df[df['Rating'] == 5.0]
print(sample.shape)
sample.head()
# Out:
# (210, 6)
#                   Strain    Type  Rating  \
# 16                831-Og  indica     5.0
# 32            Acid-Dough  sativa     5.0
# 47            Afghanimal  indica     5.0
# 62  Alaska-Thunder-Grape  hybrid     5.0
# 67                   Alf  hybrid     5.0
#
#                                       Effects                   Flavor  \
# 16                                       None                     None
# 32      Talkative,Giggly,Happy,Hungry,Relaxed                     None
# 47      Hungry,Relaxed,Aroused,Sleepy,Focused             Citrus,Skunk
# 62  Tingly,Uplifted,Creative,Euphoric,Focused  Pepper,Strawberry,Grape
# 67     Relaxed,Creative,Euphoric,Giggly,Happy  Diesel,Tropical,Pungent
#
#                                           Description
# 16  831 OG, aka Santa Cruz OG, is an indica-domina...
# 32  Acid Dough by Ripper Seeds is a sativa-dominan...
# 47  Afghanimal by In House Genetics is a heavy ind...
# 62  From Sonoma County comes Alaska Thunder Grape,...
# 67  The indica-dominant hybrid Alf was created by ...

# %%
sample = sample.dropna()
print(sample.shape)
sample.head()
# Out:
# (199, 6)
#                   Strain    Type  Rating  \
# 16                831-Og  indica     5.0
# 32            Acid-Dough  sativa     5.0
# 47            Afghanimal  indica     5.0
# 62  Alaska-Thunder-Grape  hybrid     5.0
# 67                   Alf  hybrid     5.0
#
#                                       Effects                   Flavor  \
# 16                                       None                     None
# 32      Talkative,Giggly,Happy,Hungry,Relaxed                     None
# 47      Hungry,Relaxed,Aroused,Sleepy,Focused             Citrus,Skunk
# 62  Tingly,Uplifted,Creative,Euphoric,Focused  Pepper,Strawberry,Grape
# 67     Relaxed,Creative,Euphoric,Giggly,Happy  Diesel,Tropical,Pungent
#
#                                           Description
# 16  831 OG, aka Santa Cruz OG, is an indica-domina...
# 32  Acid Dough by Ripper Seeds is a sativa-dominan...
# 47  Afghanimal by In House Genetics is a heavy ind...
# 62  From Sonoma County comes Alaska Thunder Grape,...
# 67  The indica-dominant hybrid Alf was created by ...

# %%
import numpy as np
sample["Effects"] = sample['Effects'].replace("None", np.nan)
sample["Flavor"] = sample['Flavor'].replace("None", np.nan)

print(sample.shape)
sample.head()
# Out:
# (199, 6)
#                   Strain    Type  Rating  \
# 16                831-Og  indica     5.0
# 32            Acid-Dough  sativa     5.0
# 47            Afghanimal  indica     5.0
# 62  Alaska-Thunder-Grape  hybrid     5.0
# 67                   Alf  hybrid     5.0
#
#                                       Effects                   Flavor  \
# 16                                        NaN                      NaN
# 32      Talkative,Giggly,Happy,Hungry,Relaxed                      NaN
# 47      Hungry,Relaxed,Aroused,Sleepy,Focused             Citrus,Skunk
# 62  Tingly,Uplifted,Creative,Euphoric,Focused  Pepper,Strawberry,Grape
# 67     Relaxed,Creative,Euphoric,Giggly,Happy  Diesel,Tropical,Pungent
#
#                                           Description
# 16  831 OG, aka Santa Cruz OG, is an indica-domina...
# 32  Acid Dough by Ripper Seeds is a sativa-dominan...
# 47  Afghanimal by In House Genetics is a heavy ind...
# 62  From Sonoma County comes Alaska Thunder Grape,...
# 67  The indica-dominant hybrid Alf was created by ...

# %%
sample = sample.dropna()
print(sample.shape)
sample.head()
# Out:
# (167, 6)
#                   Strain    Type  Rating  \
# 47            Afghanimal  indica     5.0
# 62  Alaska-Thunder-Grape  hybrid     5.0
# 67                   Alf  hybrid     5.0
# 72           Alien-Bubba  indica     5.0
# 88               Allkush  indica     5.0
#
#                                       Effects                     Flavor  \
# 47      Hungry,Relaxed,Aroused,Sleepy,Focused               Citrus,Skunk
# 62  Tingly,Uplifted,Creative,Euphoric,Focused    Pepper,Strawberry,Grape
# 67     Relaxed,Creative,Euphoric,Giggly,Happy    Diesel,Tropical,Pungent
# 72     Relaxed,Sleepy,Euphoric,Happy,Uplifted         Earthy,Woody,Sweet
# 88              Relaxed,Sleepy,Uplifted,Happy  Spicy/Herbal,Honey,Earthy
#
#                                           Description
# 47  Afghanimal by In House Genetics is a heavy ind...
# 62  From Sonoma County comes Alaska Thunder Grape,...
# 67  The indica-dominant hybrid Alf was created by ...
# 72  Alien Bubba is the intergalactic cross of the ...
# 88  Allkush, 2nd prize winner at the 2005 Highlife...

# %%
sample["Type"].value_counts(normalize=True)
# Out:
# hybrid    0.502994
# indica    0.341317
# sativa    0.155689
# Name: Type, dtype: float64

# %%
sample = sample.reset_index()

# %%
nice_buds = []
undesired_effects = ["Sleepy", "Hungry", "Giggly", "Tingly", "Aroused", "Talkative"]

for row in sample["Effects"]:
    if "Sleepy" not in row and "Hungry" not in row and "Giggly" not in row and "Tingly" not in row and "Aroused" not in row and "Talkative" not in row:
        nice_buds.append(1)
    else:
        nice_buds.append(0)
            
sample["nice_buds"] = nice_buds

# %%
good = []
undesired_effects = ["Sleepy", "Hungry", "Giggly", "Tingly", "Aroused", "Talkative"]

for row in sample["Effects"]:
    if all(effect not in row for effect in undesired_effects):
        good.append(1)
    else:
        good.append(0)

sample["good"] = good

### D.R.Y. success!

# %%
sample = sample.drop("nice", axis=1)
nice = []
undesired_effects = ["Sleepy", "Hungry", "Giggly", "Tingly", "Aroused", "Talkative"]

for row in sample["Effects"]:
    if any(effect not in row for effect in undesired_effects):
        nice.append(1)
    else:
        nice.append(0)

sample["nice"] = nice

### This one doesn't quite do what I want ...

# %%
undesired_effects = ["Sleepy", "Hungry", "Giggly", "Tingly", "Aroused", "Talkative"]

sample['nice buds'] = np.where(sample['Effects'].str.contains('|'.join(undesired_effects)), 0, 1)

### Also works in D.R.Y. fashion! Although perhaps a bit less readable ...

# %%
sample.head()
# Out:
#    index                Strain    Type  Rating  \
# 0     47            Afghanimal  indica     5.0
# 1     62  Alaska-Thunder-Grape  hybrid     5.0
# 2     67                   Alf  hybrid     5.0
# 3     72           Alien-Bubba  indica     5.0
# 4     88               Allkush  indica     5.0
#
#                                      Effects                     Flavor  \
# 0      Hungry,Relaxed,Aroused,Sleepy,Focused               Citrus,Skunk
# 1  Tingly,Uplifted,Creative,Euphoric,Focused    Pepper,Strawberry,Grape
# 2     Relaxed,Creative,Euphoric,Giggly,Happy    Diesel,Tropical,Pungent
# 3     Relaxed,Sleepy,Euphoric,Happy,Uplifted         Earthy,Woody,Sweet
# 4              Relaxed,Sleepy,Uplifted,Happy  Spicy/Herbal,Honey,Earthy
#
#                                          Description  nice_buds  good  nice  \
# 0  Afghanimal by In House Genetics is a heavy ind...          0     0     1
# 1  From Sonoma County comes Alaska Thunder Grape,...          0     0     1
# 2  The indica-dominant hybrid Alf was created by ...          0     0     1
# 3  Alien Bubba is the intergalactic cross of the ...          0     0     1
# 4  Allkush, 2nd prize winner at the 2005 Highlife...          0     0     1
#
#    nice buds
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
best_strains = sample[sample['nice_buds'] == 1]
print(best_strains.shape)
best_strains.head(50)
# Out:
# (32, 8)
#      index                  Strain    Type  Rating  \
# 15     194    Bertberry-Cheesecake  sativa     5.0
# 18     223        Black-Cherry-Pie  hybrid     5.0
# 19     249         Blackberry-Fire  hybrid     5.0
# 21     326             Blue-Wonder  hybrid     5.0
# 22     333          Blueberry-Bomb  hybrid     5.0
# 25     369             Brain-Candy  hybrid     5.0
# 34     497              Cherwillie  hybrid     5.0
# 56     774        Euphoria-Cookies  hybrid     5.0
# 63     840                  Gi-001  hybrid     5.0
# 64     844         Gabriel-Sherbet  hybrid     5.0
# 65     846            Galactica-Og  indica     5.0
# 71     913  Grandmas-Sugar-Cookies  indica     5.0
# 73     938           Green-Avenger  hybrid     5.0
# 80     990             Harley-Twin  sativa     5.0
# 81    1005     Hawaiian-Mayan-Gold  sativa     5.0
# 83    1058       Huckleberry-Hound  hybrid     5.0
# 90    1161                 Kali-47  sativa     5.0
# 102   1385           Mekamika-Haze  sativa     5.0
# 107   1419               Moondance  sativa     5.0
# 111   1478     Northwest-Pineapple  hybrid     5.0
# 120   1603          Pineapple-Sage  sativa     5.0
# 125   1667           Purple-Aurora  hybrid     5.0
# 129   1742                     R-4  hybrid     5.0
# 132   1755          Rebel-Berry-Og  hybrid     5.0
# 135   1808      Royal-Tree-Sherbet  hybrid     5.0
# 139   1873          Silverhawks-Og  sativa     5.0
# 141   1896                Smelliot  hybrid     5.0
# 146   1982              Spyder-Mon  hybrid     5.0
# 154   2133              The-Blintz  hybrid     5.0
# 155   2140                The-Gift  hybrid     5.0
# 158   2243                     Wtf  hybrid     5.0
# 165   2343             Zellys-Gift  sativa     5.0
#
#                                           Effects  \
# 15   Uplifted,Creative,Euphoric,Focused,Energetic
# 18       Relaxed,Uplifted,Creative,Euphoric,Happy
# 19                                 Creative,Happy
# 21        Uplifted,Happy,Euphoric,Focused,Relaxed
# 22                                        Relaxed
# 25                                       Creative
# 34       Creative,Energetic,Happy,Relaxed,Focused
# 56       Euphoric,Creative,Uplifted,Happy,Relaxed
# 63   Creative,Focused,Energetic,Uplifted,Euphoric
# 64        Euphoric,Relaxed,Uplifted,Happy,Focused
# 65                       Euphoric,Focused,Relaxed
# 71       Relaxed,Happy,Energetic,Focused,Creative
# 73     Energetic,Happy,Uplifted,Creative,Euphoric
# 80   Uplifted,Creative,Energetic,Euphoric,Relaxed
# 81     Uplifted,Creative,Energetic,Euphoric,Happy
# 83                Creative,Euphoric,Happy,Relaxed
# 90     Uplifted,Creative,Energetic,Euphoric,Happy
# 102  Uplifted,Creative,Energetic,Euphoric,Focused
# 107               Creative,Euphoric,Happy,Relaxed
# 111               Uplifted,Euphoric,Happy,Relaxed
# 120  Uplifted,Creative,Energetic,Euphoric,Focused
# 125                               Focused,Relaxed
# 129       Uplifted,Happy,Relaxed,Creative,Focused
# 132      Euphoric,Happy,Uplifted,Relaxed,Creative
# 135                                       Relaxed
# 139      Euphoric,Relaxed,Uplifted,Creative,Happy
# 141      Uplifted,Happy,Creative,Euphoric,Focused
# 146       Uplifted,Creative,Focused,Happy,Relaxed
# 154     Uplifted,Creative,Energetic,Focused,Happy
# 155                              Uplifted,Relaxed
# 158      Happy,Energetic,Focused,Relaxed,Creative
# 165     Happy,Uplifted,Energetic,Relaxed,Euphoric
#
#                           Flavor  \
# 15       Cheese,Berry,Tree,Fruit
# 18            Earthy,Berry,Sweet
# 19         Sweet,Berry,Blueberry
# 21                     Blueberry
# 22                  Berry,Citrus
# 25                         Sweet
# 34       Sweet,Strawberry,Citrus
# 56         Sweet,Citrus,Tropical
# 63             Citrus,Lime,Lemon
# 64             Berry,Minty,Sweet
# 65   Spicy/Herbal,Earthy,Pungent
# 71          Pungent,Sweet,Cheese
# 73             Sweet,Minty,Honey
# 80                         Sweet
# 81              Minty,Sweet,Lime
# 83      Blueberry,Skunk,Chemical
# 90                 Sweet,Vanilla
# 102      Pineapple,Mango,Flowery
# 107                Lavender,Pine
# 111              Sweet,Pineapple
# 120             Sage,Sweet,Lemon
# 125        Berry,Blueberry,Grape
# 129    Earthy,Nutty,Spicy/Herbal
# 132     Blueberry,Cheese,Vanilla
# 135         Tropical,Sweet,Berry
# 139          Lime,Citrus,Flowery
# 141         Citrus,Ammonia,Sweet
# 146          Citrus,Earthy,Sweet
# 154      Lavender,Earthy,Pungent
# 155                 Sweet,Earthy
# 158       Skunk,Blueberry,Earthy
# 165            Sweet,Citrus,Lime
#
#                                            Description  nice_buds
# 15   Bertberry Cheesecake by Bert Baccarat is a bri...          1
# 18   Black Cherry Pie is a fruity strain with color...          1
# 19   Blackberry Fire by Purple Caper Seeds is a fue...          1
# 21   Blue Wonder is a sativa-dominant hybrid origin...          1
# 22   Blueberry Bomb is an indica-dominant hybrid cr...          1
# 25   Brain Candy by Insanity Strains is a handy hyb...          1
# 34   CherWillie is the sativa-dominant hybrid cross...          1
# 56   Euphoria Cookies is a balanced 50/50 hybrid cr...          1
# 63   GI001 is a sativa-dominant cannabis strain dev...          1
# 64   Sherbet by Gabriel Cannabis is a special cross...          1
# 65   Galactica OG by Palomar Craft Cannabis is an i...          1
# 71   Grandma’s Sugar Cookies by Johnston’s Genetics...          1
# 73   The celebrated breeder Subcool is well-known f...          1
# 80   Harley Twin is a CBD-rich, sativa-dominant str...          1
# 81   What do you get when you cross two of the most...          1
# 83   Huckleberry Hound is an obscure hybrid that ha...          1
# 90   Kali 47 is a mostly sativa strain that is char...          1
# 102  Mekamika Haze won Best Sativa at the 2015 Amst...          1
# 107  Moondance is a sativa-dominant strain that off...          1
# 111  Northwest Pineapple is an indica-dominant hybr...          1
# 120  Pineapple Sage by Love Genetics is a backcross...          1
# 125  New from breeders Alaska Built, Purple Aurora ...          1
# 129  R-4, also known as Cindy’s Solution, is a CBD-...          1
# 132  Rebel Berry OG was the winner for Best Outdoor...          1
# 135  Sherbet by Royal Tree Gardens is another genet...          1
# 139  Silverhawks OG is a strong cross between Super...          1
# 141  Smelliot, named after its flavorful and pungen...          1
# 146  Spyder Mon is an uplifting CBD strain with a g...          1
# 154  Bred by Terraform Genetics, The Bintz is a den...          1
# 155  The Gift is a Ringo’s Gift backcross created f...          1
# 158  WTF by White Tygh Farms is an odd cross of CBD...          1
# 165  Zelly’s Gift by Dragonfly Earth Medicine is a ...          1

# %%
best_strains['Type'].value_counts(normalize=True)
# Out:
# hybrid    0.65625
# sativa    0.28125
# indica    0.06250
# Name: Type, dtype: float64

# %%
best_strains = best_strains.reset_index()

# %%
best_strains.head()
# Out:
#    level_0  index                Strain    Type  Rating  \
# 0       15    194  Bertberry-Cheesecake  sativa     5.0
# 1       18    223      Black-Cherry-Pie  hybrid     5.0
# 2       19    249       Blackberry-Fire  hybrid     5.0
# 3       21    326           Blue-Wonder  hybrid     5.0
# 4       22    333        Blueberry-Bomb  hybrid     5.0
#
#                                         Effects                   Flavor  \
# 0  Uplifted,Creative,Euphoric,Focused,Energetic  Cheese,Berry,Tree,Fruit
# 1      Relaxed,Uplifted,Creative,Euphoric,Happy       Earthy,Berry,Sweet
# 2                                Creative,Happy    Sweet,Berry,Blueberry
# 3       Uplifted,Happy,Euphoric,Focused,Relaxed                Blueberry
# 4                                       Relaxed             Berry,Citrus
#
#                                          Description  nice_buds
# 0  Bertberry Cheesecake by Bert Baccarat is a bri...          1
# 1  Black Cherry Pie is a fruity strain with color...          1
# 2  Blackberry Fire by Purple Caper Seeds is a fue...          1
# 3  Blue Wonder is a sativa-dominant hybrid origin...          1
# 4  Blueberry Bomb is an indica-dominant hybrid cr...          1

# %%
best_strains = best_strains.drop(["level_0","index"], axis=1)
best_strains.head()
# Out:
#                  Strain    Type  Rating  \
# 0  Bertberry-Cheesecake  sativa     5.0
# 1      Black-Cherry-Pie  hybrid     5.0
# 2       Blackberry-Fire  hybrid     5.0
# 3           Blue-Wonder  hybrid     5.0
# 4        Blueberry-Bomb  hybrid     5.0
#
#                                         Effects                   Flavor  \
# 0  Uplifted,Creative,Euphoric,Focused,Energetic  Cheese,Berry,Tree,Fruit
# 1      Relaxed,Uplifted,Creative,Euphoric,Happy       Earthy,Berry,Sweet
# 2                                Creative,Happy    Sweet,Berry,Blueberry
# 3       Uplifted,Happy,Euphoric,Focused,Relaxed                Blueberry
# 4                                       Relaxed             Berry,Citrus
#
#                                          Description  nice_buds
# 0  Bertberry Cheesecake by Bert Baccarat is a bri...          1
# 1  Black Cherry Pie is a fruity strain with color...          1
# 2  Blackberry Fire by Purple Caper Seeds is a fue...          1
# 3  Blue Wonder is a sativa-dominant hybrid origin...          1
# 4  Blueberry Bomb is an indica-dominant hybrid cr...          1

# %%
export = best_strains.drop(["Rating", "Description", "nice_buds"], axis=1)
export.head()
# Out:
#                  Strain    Type                                       Effects  \
# 0  Bertberry-Cheesecake  sativa  Uplifted,Creative,Euphoric,Focused,Energetic
# 1      Black-Cherry-Pie  hybrid      Relaxed,Uplifted,Creative,Euphoric,Happy
# 2       Blackberry-Fire  hybrid                                Creative,Happy
# 3           Blue-Wonder  hybrid       Uplifted,Happy,Euphoric,Focused,Relaxed
# 4        Blueberry-Bomb  hybrid                                       Relaxed
#
#                     Flavor
# 0  Cheese,Berry,Tree,Fruit
# 1       Earthy,Berry,Sweet
# 2    Sweet,Berry,Blueberry
# 3                Blueberry
# 4             Berry,Citrus

# %%
export.to_csv("/Users/ekselan/Documents/ABW/data/best_strains3.csv")

# %% [markdown]
# # Tokens

# %% [markdown]
# ## Definitions

# %% [markdown]
# Define the following terms in your own words, do not simply copy and paste a definition found elsewhere but reword it to be understandable and memorable to you. *Double click the markdown to add your definitions.*
# <br/><br/>
#
# **Natural Language Processing**: `Your Answer Here`
#
# **Token**: `Your Answer Here`
#
# **Corpus**: `Your Answer Here`
#
# **Stopwords**: `Your Answer Here`
#
# **Statistical Trimming**: `Your Answer Here`
#
# **Stemming**: `Your Answer Here`
#
# **Lemmatization**: `Your Answer Here`
#
# **Vectorization**: `Your Answer Here`

# %% [markdown]
# ## Questions of Understanding

# %% [markdown]
# 1. What are at least 4 common cleaning tasks you need to do when creating tokens?
#  1. `Your Answer Here`
#  2. `Your Answer Here`
#  3. `Your Answer Here`
#  4. `Your Answer Here`
#
# 2. Why is it important to apply custom stopwords to our dataset in addition to the ones that come in a library like spaCy?
# ```
# Your Answer Here
# ```
#
# 3. Explain the tradeoffs between statistical trimming, stemming, and lemmatizing.
# ```
# Your Answer Here
# ```
#
# 4. Why do we need to vectorize our documents?
# ```
# Your Answer Here
# ```

# %% [markdown]
# ## Practice Problems

# %% [markdown]
# Write a function to tokenize the `Description` column. Make sure to include the following:
# - Return the tokens in an iterable structure
# - Normalize the case
# - Remove non-alphanumeric characters such as punctuation, whitespace, unicode, etc.
# - Apply stopwords and make sure to add stopwords specific to this dataset
# - Lemmatize the tokens before returning them

# %% [markdown]
# Apply your function to `Description` and save the resulting tokens in a new column, `Tokens`

# %% [markdown]
# Use the function below to create a `word_count` dataframe based off the `df['Tokens']` column you created.

# %%
def count(docs):
        word_counts = Counter()
        appears_in = Counter()
        total_docs = len(docs)

        for doc in docs:
            word_counts.update(doc)
            appears_in.update(set(doc))

        temp = zip(word_counts.keys(), word_counts.values())
        wc = pd.DataFrame(temp, columns = ['word', 'count'])

        wc['rank'] = wc['count'].rank(method='first', ascending=False)
        total = wc['count'].sum()

        wc['pct_total'] = wc['count'].apply(lambda x: x / total)
        
        wc = wc.sort_values(by='rank')
        wc['cul_pct_total'] = wc['pct_total'].cumsum()

        t2 = zip(appears_in.keys(), appears_in.values())
        ac = pd.DataFrame(t2, columns=['word', 'appears_in'])
        wc = ac.merge(wc, on='word')

        wc['appears_in_pct'] = wc['appears_in'].apply(lambda x: x / total_docs)
        
        return wc.sort_values(by='rank')

# %% [markdown]
# Run the line of code below, and then explain how to interpret the graph.
#
# ```
# Your Answer Here
# ```

# %%
sns.lineplot(x='rank', y='cul_pct_total', data=word_count);

# %% [markdown]
# # Vectorization

# %% [markdown]
# ## Definitions

# %% [markdown]
# Define the following terms in your own words, do not simply copy and paste a definition found elsewhere but reword it to be understandable and memorable to you. *Double click the markdown to add your definitions.*
# <br/><br/>
#
# **Vectorization**: `Your Answer Here`
#
# **Document Term Matrix (DTM)**: `Your Answer Here`
#
# **Latent Semantic Analysis**: `Your Answer Here`
#
# **Term Frequency - Inverse Document Frequency (TF-IDF)**: `Your Answer Here`
#
# **Word Embedding**: `Your Answer Here`
#
# **N-Gram**: `Your Answer Here`
#
# **Skip-Gram**: `Your Answer Here`

# %% [markdown]
# ## Questions of Understanding

# %% [markdown]
# 1. Why do we need to vectorize our documents?
# ```
# Your Answer Here
# ```
#
# 2. How is TF-IDF different from simple word frequency? Why do we use TF-IDF over word frequency?
# ```
# Your Answer Here
# ```
#
# 3. Why might we choose a word embedding approach over a bag-of-words approach when it comes to vectorization?
# ```
# Your Answer Here
# ```

# %% [markdown]
# ## Practice Problems

# %% [markdown]
# Use the dataframe `df` above to complete the following.

# %% [markdown]
# Vectorize the `Tokens` column.

# %% [markdown]
# Build a Nearest Neighbors model from your dataframe and then find the 5 nearest neighbors to the strain "100-OG"

# %% [markdown]
# You will be putting together a classification model below, but before you do you'll need a baseline. Run the line of code below and then find the normalized value counts for the `Rating` column in `df`.

# %%
df['Rating'] = df['Rating'].round().astype(int)

# %% [markdown]
# What is the baseline accuracy?
# ```
# Your Answer Here
# ```
#
# Visualize the rating counts from above

# %% [markdown]
# Use your vectorized tokens in the `df` dataframe to train a classification model

# %% [markdown]
# Predict the score of the fake strain description below.
#
# ```
# 'Afgooey, also known as Afgoo, is a potent indica strain that is believed to descend from an Afghani indica and Maui Haze.
# Its sativa parent may lend Afgoo some uplifting, creative qualities, but this strain undoubtedly takes after its indica
# parent as it primarily delivers relaxing, sleepy effects alongside its earthy pine flavor. Growers hoping to cultivate Afgoo
# may have a better chance of success indoors, but this indica can also thrive in Mediterranean climates outdoors.'
# ```

# %% [markdown]
# # Topic Modeling

# %% [markdown]
# ## Questions of Understanding

# %% [markdown]
# 1. What is Latent Dirichlet Allocation? What is another name for LDA in NLP?
# ```
# Your Answer Here
# ```
#
# 2. How do interpret the results of a topic modeling output?
# ```
# Your Answer Here
# ```

# %% [markdown]
# ## Practice Problems

# %% [markdown]
# Find the top 5 topics of the `Description` column using LDA

# %% [markdown]
# In a short paragraph, explain how to interpret the first topic your model came up with. If your topic words are difficult to interpret, explain how you could clean up the descriptions to improve your topics
#
# ```
# Your Answer Here
# ```

# %% [markdown]
# Use `pyLDAvis` to create a visualization to help you interpret your topic modeling results

# %% [markdown]
# Explain how to interpret the results of `pyLDAvis`
#
# ```
# Your Answer Here
# ```

# %% [markdown]
# Create at least 1 more visualization to help you interpret the results of your topic modeling
